# %% [markdown]
# # **3D-UNET For Multimodal Brain Tumor Segmentation**

# %%
# importing all libraries

import tensorflow
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv3D, MaxPooling3D, UpSampling3D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv3D, Conv3DTranspose, MaxPooling3D, BatchNormalization, Activation, Concatenate
from tensorflow.keras.models import Model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout,Maximum

# %%
# Convolutional blocks for the U_Net model
def conv_block(input_mat,num_filters,kernel_size,batch_norm):
  X = Conv3D(num_filters,kernel_size=(kernel_size,kernel_size,kernel_size),strides=(1,1,1),padding='same')(input_mat)
  X = BatchNormalization()(X)
  X = Activation('leaky_relu')(X)

  X = Conv3D(num_filters,kernel_size=(kernel_size,kernel_size,kernel_size),strides=(1,1,1),padding='same')(X)
  X = BatchNormalization()(X)
  X = Activation('leaky_relu')(X)

  return X

# %%
# Define the 3D U-Net model
def Unet_3d(input_img, n_filters=8, dropout=0.2, batch_norm=True):
    # Contracting path
    conv_1 = conv_block(input_img, n_filters, 3, batch_norm)
    pool_1 = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2))(conv_1)
    pool_1 = Dropout(dropout)(pool_1)

    conv_2 = conv_block(pool_1, n_filters * 2, 3, batch_norm)
    pool_2 = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2))(conv_2)
    pool_2 = Dropout(dropout)(pool_2)

    conv_3 = conv_block(pool_2, n_filters * 4, 3, batch_norm)
    pool_3 = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2))(conv_3)
    pool_3 = Dropout(dropout)(pool_3)

    conv_4 = conv_block(pool_3, n_filters * 8, 3, batch_norm)
    pool_4 = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2))(conv_4)
    pool_4 = Dropout(dropout)(pool_4)

    conv_5 = conv_block(pool_4, n_filters * 16, 3, batch_norm)

    # Expansive path
    up_conv_6 = Conv3DTranspose(n_filters * 8, 3, strides=(2, 2, 2), padding='same')(conv_5)
    up_conv_6 = concatenate([up_conv_6, conv_4])
    conv_6 = conv_block(up_conv_6, n_filters * 8, 3, batch_norm)
    conv_6 = Dropout(dropout)(conv_6)

    up_conv_7 = Conv3DTranspose(n_filters * 4, 3, strides=(2, 2, 2), padding='same')(conv_6)
    up_conv_7 = concatenate([up_conv_7, conv_3])
    conv_7 = conv_block(up_conv_7, n_filters * 4, 3, batch_norm)
    conv_7 = Dropout(dropout)(conv_7)

    up_conv_8 = Conv3DTranspose(n_filters * 2, 3, strides=(2, 2, 2), padding='same')(conv_7)
    up_conv_8 = concatenate([up_conv_8, conv_2])
    conv_8 = conv_block(up_conv_8, n_filters * 2, 3, batch_norm)
    conv_8 = Dropout(dropout)(conv_8)

    up_conv_9 = Conv3DTranspose(n_filters, 3, strides=(2, 2, 2), padding='same')(conv_8)
    up_conv_9 = concatenate([up_conv_9, conv_1])
    conv_9 = conv_block(up_conv_9, n_filters, 3, batch_norm)

    # Output layer
    outputs = Conv3D(4, (1, 1, 1), activation='softmax')(conv_9)

    model = Model(inputs=input_img, outputs=outputs)

    return model

# %%
#Building the 3D-Unet Model.
input_img = Input((128,128,128,4))
model = Unet_3d(input_img,8,0.1,True)

# %%
print(model.input_shape)
print(model.output_shape)
# Out:
# (None, 128, 128, 128, 4)
# (None, 128, 128, 128, 4)

# %%
# printing the summary of the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 128, 4)]   0         []
#
#  conv3d_1 (Conv3D)           (None, 128, 128, 128, 8)     872       ['input_2[0][0]']
#
#  batch_normalization (Batch  (None, 128, 128, 128, 8)     32        ['conv3d_1[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 128, 128, 128, 8)     0         ['batch_normalization[0][0]']
#
#  conv3d_2 (Conv3D)           (None, 128, 128, 128, 8)     1736      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128, 128, 128, 8)     32        ['conv3d_2[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 128, 128, 128, 8)     0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling3d (MaxPooling3  (None, 64, 64, 64, 8)        0         ['activation_1[0][0]']
#  D)
#
#  dropout (Dropout)           (None, 64, 64, 64, 8)        0         ['max_pooling3d[0][0]']
#
#  conv3d_3 (Conv3D)           (None, 64, 64, 64, 16)       3472      ['dropout[0][0]']
#
#  batch_normalization_2 (Bat  (None, 64, 64, 64, 16)       64        ['conv3d_3[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64, 64, 64, 16)       0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv3d_4 (Conv3D)           (None, 64, 64, 64, 16)       6928      ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 64, 64, 64, 16)       64        ['conv3d_4[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 64, 64, 64, 16)       0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling3d_1 (MaxPoolin  (None, 32, 32, 32, 16)       0         ['activation_3[0][0]']
#  g3D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 32, 16)       0         ['max_pooling3d_1[0][0]']
#
#  conv3d_5 (Conv3D)           (None, 32, 32, 32, 32)       13856     ['dropout_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 32, 32, 32, 32)       128       ['conv3d_5[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 32, 32, 32, 32)       0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv3d_6 (Conv3D)           (None, 32, 32, 32, 32)       27680     ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 32, 32, 32, 32)       128       ['conv3d_6[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 32, 32, 32, 32)       0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling3d_2 (MaxPoolin  (None, 16, 16, 16, 32)       0         ['activation_5[0][0]']
#  g3D)
#
#  dropout_2 (Dropout)         (None, 16, 16, 16, 32)       0         ['max_pooling3d_2[0][0]']
#
#  conv3d_7 (Conv3D)           (None, 16, 16, 16, 64)       55360     ['dropout_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 16, 16, 16, 64)       256       ['conv3d_7[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 16, 16, 16, 64)       0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv3d_8 (Conv3D)           (None, 16, 16, 16, 64)       110656    ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 16, 16, 16, 64)       256       ['conv3d_8[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 16, 16, 16, 64)       0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  max_pooling3d_3 (MaxPoolin  (None, 8, 8, 8, 64)          0         ['activation_7[0][0]']
#  g3D)
#
#  dropout_3 (Dropout)         (None, 8, 8, 8, 64)          0         ['max_pooling3d_3[0][0]']
#
#  conv3d_9 (Conv3D)           (None, 8, 8, 8, 128)         221312    ['dropout_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 8, 8, 8, 128)         512       ['conv3d_9[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 8, 8, 8, 128)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv3d_10 (Conv3D)          (None, 8, 8, 8, 128)         442496    ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 8, 8, 8, 128)         512       ['conv3d_10[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 8, 8, 8, 128)         0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv3d_transpose (Conv3DTr  (None, 16, 16, 16, 64)       221248    ['activation_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 16, 16, 16, 128)      0         ['conv3d_transpose[0][0]',
#                                                                      'activation_7[0][0]']
#
#  conv3d_11 (Conv3D)          (None, 16, 16, 16, 64)       221248    ['concatenate[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 16, 64)       256       ['conv3d_11[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 16, 16, 16, 64)       0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv3d_12 (Conv3D)          (None, 16, 16, 16, 64)       110656    ['activation_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 16, 16, 16, 64)       256       ['conv3d_12[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 16, 16, 16, 64)       0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  dropout_4 (Dropout)         (None, 16, 16, 16, 64)       0         ['activation_11[0][0]']
#
#  conv3d_transpose_1 (Conv3D  (None, 32, 32, 32, 32)       55328     ['dropout_4[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 32, 64)       0         ['conv3d_transpose_1[0][0]',
#  )                                                                   'activation_5[0][0]']
#
#  conv3d_13 (Conv3D)          (None, 32, 32, 32, 32)       55328     ['concatenate_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 32, 32, 32, 32)       128       ['conv3d_13[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 32, 32, 32, 32)       0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv3d_14 (Conv3D)          (None, 32, 32, 32, 32)       27680     ['activation_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 32, 32, 32, 32)       128       ['conv3d_14[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 32, 32, 32, 32)       0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  dropout_5 (Dropout)         (None, 32, 32, 32, 32)       0         ['activation_13[0][0]']
#
#  conv3d_transpose_2 (Conv3D  (None, 64, 64, 64, 16)       13840     ['dropout_5[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 64, 32)       0         ['conv3d_transpose_2[0][0]',
#  )                                                                   'activation_3[0][0]']
#
#  conv3d_15 (Conv3D)          (None, 64, 64, 64, 16)       13840     ['concatenate_2[0][0]']
#
#  batch_normalization_14 (Ba  (None, 64, 64, 64, 16)       64        ['conv3d_15[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 64, 64, 64, 16)       0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv3d_16 (Conv3D)          (None, 64, 64, 64, 16)       6928      ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 64, 64, 64, 16)       64        ['conv3d_16[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 64, 64, 64, 16)       0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  dropout_6 (Dropout)         (None, 64, 64, 64, 16)       0         ['activation_15[0][0]']
#
#  conv3d_transpose_3 (Conv3D  (None, 128, 128, 128, 8)     3464      ['dropout_6[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 128, 128, 128, 16)    0         ['conv3d_transpose_3[0][0]',
#  )                                                                   'activation_1[0][0]']
#
#  conv3d_17 (Conv3D)          (None, 128, 128, 128, 8)     3464      ['concatenate_3[0][0]']
#
#  batch_normalization_16 (Ba  (None, 128, 128, 128, 8)     32        ['conv3d_17[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 128, 128, 128, 8)     0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv3d_18 (Conv3D)          (None, 128, 128, 128, 8)     1736      ['activation_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 128, 128, 128, 8)     32        ['conv3d_18[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 128, 128, 128, 8)     0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv3d_19 (Conv3D)          (None, 128, 128, 128, 4)     36        ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 1622108 (6.19 MB)
# Trainable params: 1620636 (6.18 MB)
# Non-trainable params: 1472 (5.75 KB)
# __________________________________________________________________________________________________
